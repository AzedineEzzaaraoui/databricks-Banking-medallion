-- %%
select * from  banking.bronze.bronze_accounts ;
select * from  banking.bronze.bronze_branches;
select * from  banking.bronze.bronze_credit;
select * from  banking.bronze.bronze_customers;
select * from  banking.bronze.bronze_payement_gateway;
select * from  banking.bronze.bronze_transactions;
select * from  banking.bronze.execution_monitoring;
select * from  banking.silver.silver_accounts ;
select * from  banking.silver.silver_branches;
select * from  banking.silver.silver_credit;
select * from  banking.silver.silver_customers;

truncate table banking.bronze.bronze_accounts ;
truncate table banking.bronze.bronze_branches;
truncate table banking.bronze.bronze_credit;
truncate table banking.bronze.bronze_customers;
truncate table banking.bronze.bronze_payement_gateway;
truncate table banking.bronze.bronze_transactions;
truncate table banking.bronze.execution_monitoring;
truncate table banking.silver.silver_accounts ;
truncate table banking.silver.silver_branches;
truncate table banking.silver.silver_credit;
truncate table banking.silver.silver_customers;
truncate table banking.silver.silver_payement_gateway;
truncate table banking.silver.silver_transactions;
